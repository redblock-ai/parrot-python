# %%
from datasets.Datasets import Datasets

# %%
jeopardy = Datasets("jeopardy")
# Out:
# 2024-09-26 16:14:00 - INFO - [Datasets] Loading dataset: jeopardy
# 2024-09-26 16:14:00 - INFO - [Datasets] Dataset loaded successfully

# %%
jeopardy.get_dataframe()
# Out:
#       ep_num    air_date                                  extra_info  \
# 0          1  1984-09-10  Premiere episode with Alex Trebek as host.
# 1          1  1984-09-10  Premiere episode with Alex Trebek as host.
# 2          1  1984-09-10  Premiere episode with Alex Trebek as host.
# 3          1  1984-09-10  Premiere episode with Alex Trebek as host.
# 4          1  1984-09-10  Premiere episode with Alex Trebek as host.
# ...      ...         ...                                         ...
# 62513   7778  2018-06-06                                         NaN
# 62514   7778  2018-06-06                                         NaN
# 62515   7778  2018-06-06                                         NaN
# 62516   7778  2018-06-06                                         NaN
# 62517   7778  2018-06-06                                         NaN
#
#             round_name   coord                       category  \
# 0             Jeopardy  (1, 1)                 LAKES & RIVERS
# ...

# %%
millionaire_data = Datasets(dataset="millionaire")
# Out:
# 2024-09-26 16:14:00 - INFO - [Datasets] Loading dataset: millionaire
# 2024-09-26 16:14:00 - INFO - [Datasets] Dataset loaded successfully

# %%
millionaire_data.get_dataframe()
# Out:
#                       question_info  \
# 0        $100 (1 of 15) - Not Timed
# 1        $200 (2 of 15) - Not Timed
# 2        $300 (3 of 15) - Not Timed
# 3        $500 (4 of 15) - Not Timed
# 4      $1,000 (5 of 15) - Not Timed
# ...                             ...
# 22693                        $1,000
# 22694                           (1)
# 22695                           (2)
# 22696                           (3)
# 22697                $1,000,000 (4)
#
#                                                 question  \
# 0      If you like someone right away, it is said tha...
# 1      A resident of a small town is said to be a "lo...
# 2              A Brillo Pad is commonly used to do what?
# 3      On a standard hopscotch surface, what is usual...
# 4      Which of these contractions is considered to b...
# ...                                                  ...
# 22693  A survey by mattress company Ergoflex revealed...
# 22694  While visiting a Dutch museum in 2013, Justin ...
# ...
